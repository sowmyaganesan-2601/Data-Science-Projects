# %%
# !pip install pyspark
# !pip install hadoop-aws
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement hadoop-aws (from versions: none)
# ERROR: No matching distribution found for hadoop-aws

# %%
from pyspark.sql import SparkSession

# Spark Session with S3 Configuration
spark = SparkSession.builder \
    .appName("Frequent Itemsets and Association Rules") \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.2.0,com.amazonaws:aws-java-sdk:1.11.375") \
    .config("spark.hadoop.fs.s3a.access.key", "AKIA5KZB6HULCM6P5U4U") \
    .config("spark.hadoop.fs.s3a.secret.key", "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") \
    .config("spark.hadoop.fs.s3a.endpoint", "s3.amazonaws.com") \
    .getOrCreate()

# %%
# Save frequent itemsets to S3 as Parquet
frequent_itemsets.write.mode("overwrite").parquet("s3a://my-spark-buckets/frequent_itemsets/")

# Save association rules to S3 as Parquet
association_rules.write.mode("overwrite").parquet("s3a://my-spark-buckets/association_rules/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Save frequent itemsets to S3 as Parquet
# ----> 2 frequent_itemsets.write.mode("overwrite").parquet("s3a://my-spark-buckets/frequent_itemsets/")
#       4 # Save association rules to S3 as Parquet
#       5 association_rules.write.mode("overwrite").parquet("s3a://my-spark-buckets/association_rules/")
#
# NameError: name 'frequent_itemsets' is not defined
